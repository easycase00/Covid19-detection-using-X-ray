# %%
import pandas as pd
import os
import shutil

# %% [markdown]
# ## Creating dataset for +ve samples

# %%
File_path= 'C:/Users/Admin/PycharmProjects/Covid-19-detection-using-X-rays/covid-chestxray-dataset-master/metadata.csv'
Image_path= 'C:/Users/Admin/PycharmProjects/Covid-19-detection-using-X-rays/covid-chestxray-dataset-master/images/'

# %%
df= pd.read_csv(File_path)
df.shape
# Out:
# (950, 30)

# %%
df.head()
# Out:
#   patientid  offset sex   age                   finding RT_PCR_positive  \
# 0         2     0.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 1         2     3.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 2         2     5.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 3         2     6.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 4         4     0.0   F  52.0  Pneumonia/Viral/COVID-19               Y
#
#   survival intubated intubation_present went_icu  ...              date  \
# 0        Y         N                  N        N  ...  January 22, 2020
# 1        Y         N                  N        N  ...  January 25, 2020
# 2        Y         N                  N        N  ...  January 27, 2020
# 3        Y         N                  N        N  ...  January 28, 2020
# 4      NaN         N                  N        N  ...  January 25, 2020
#
#                                             location  folder  \
# ...

# %%
Target_dir= 'Dataset/Covid'

if not os.path.exists(Target_dir):
    os.mkdir(Target_dir)
    print("folder created")
else:
    print('already created')
# Out:
# already created

# %%
counter = 0

for (i,row) in df.iterrows() :
    if row["finding"]=="Pneumonia/Viral/COVID-19" and row["view"]=="PA":
        filename= row["filename"]
        image_path= os.path.join(Image_path, filename)
        image_copy_path= os.path.join(Target_dir, filename)
        shutil.copy2(image_path, image_copy_path)
        counter += 1
        print("moving image", counter)
# Out:
# moving image 1
# moving image 2
# moving image 3
# moving image 4
# moving image 5
# moving image 6
# moving image 7
# moving image 8
# moving image 9
# moving image 10
# moving image 11
# moving image 12
# moving image 13
# moving image 14
# moving image 15
# moving image 16
# moving image 17
# moving image 18
# moving image 19
# moving image 20
# moving image 21
# moving image 22
# moving image 23
# moving image 24
# moving image 25
# moving image 26
# moving image 27
# moving image 28
# moving image 29
# moving image 30
# moving image 31
# moving image 32
# moving image 33
# moving image 34
# moving image 35
# moving image 36
# moving image 37
# moving image 38
# moving image 39
# moving image 40
# moving image 41
# moving image 42
# moving image 43
# moving image 44
# moving image 45
# moving image 46
# moving image 47
# moving image 48
# moving image 49
# moving image 50
# moving image 51
# moving image 52
# moving image 53
# moving image 54
# moving image 55
# moving image 56
# ...

# %% [markdown]
# ## Making dataset for normal/-ve images

# %%
import random
Kaggle_file_path= "chest_xray/chest_xray/train/NORMAL"
Target_normal_dir= "Dataset/Normal"

# %%
image_names= os.listdir(Kaggle_file_path)

random.shuffle(image_names)
print(image_names)
# Out:
# ['NORMAL2-IM-0689-0001.jpeg', 'IM-0273-0001.jpeg', 'IM-0125-0001.jpeg', 'NORMAL2-IM-1362-0001.jpeg', 'IM-0250-0001.jpeg', 'IM-0636-0001.jpeg', 'IM-0238-0001.jpeg', 'IM-0128-0001.jpeg', 'IM-0543-0001.jpeg', 'NORMAL2-IM-0803-0001.jpeg', 'IM-0733-0001.jpeg', 'NORMAL2-IM-0774-0001.jpeg', 'NORMAL2-IM-0993-0001.jpeg', 'IM-0688-0001.jpeg', 'IM-0274-0001.jpeg', 'IM-0147-0001.jpeg', 'IM-0524-0001.jpeg', 'NORMAL2-IM-0852-0001.jpeg', 'IM-0384-0001.jpeg', 'IM-0395-0001.jpeg', 'NORMAL2-IM-1173-0001.jpeg', 'NORMAL2-IM-0662-0001.jpeg', 'IM-0717-0001.jpeg', 'NORMAL2-IM-0976-0001.jpeg', 'IM-0667-0001.jpeg', 'NORMAL2-IM-0390-0001.jpeg', 'NORMAL2-IM-0552-0001.jpeg', 'NORMAL2-IM-0904-0001.jpeg', 'NORMAL2-IM-0428-0001.jpeg', 'NORMAL2-IM-0555-0001-0001.jpeg', 'IM-0199-0001.jpeg', 'NORMAL2-IM-0957-0001.jpeg', 'NORMAL2-IM-0929-0001.jpeg', 'NORMAL2-IM-1422-0001.jpeg', 'IM-0752-0001.jpeg', 'IM-0405-0001.jpeg', 'IM-0629-0001-0003.jpeg', 'NORMAL2-IM-0620-0001.jpeg', 'NORMAL2-IM-0772-0001.jpeg', 'NORMAL2-IM-0824
# ...

# %%
for i in range(196):
    image_name= image_names[i]
    print(image_name)
    
    image_path= os.path.join(Kaggle_file_path, image_name)
    
    target_path= os.path.join(Target_normal_dir, image_name)
    
    shutil.copy2(image_path, target_path)
    
    print("copying image", i)
# Out:
# NORMAL2-IM-0689-0001.jpeg
# copying image 0
# IM-0273-0001.jpeg
# copying image 1
# IM-0125-0001.jpeg
# copying image 2
# NORMAL2-IM-1362-0001.jpeg
# copying image 3
# IM-0250-0001.jpeg
# copying image 4
# IM-0636-0001.jpeg
# copying image 5
# IM-0238-0001.jpeg
# copying image 6
# IM-0128-0001.jpeg
# copying image 7
# IM-0543-0001.jpeg
# copying image 8
# NORMAL2-IM-0803-0001.jpeg
# copying image 9
# IM-0733-0001.jpeg
# copying image 10
# NORMAL2-IM-0774-0001.jpeg
# copying image 11
# NORMAL2-IM-0993-0001.jpeg
# copying image 12
# IM-0688-0001.jpeg
# copying image 13
# IM-0274-0001.jpeg
# copying image 14
# IM-0147-0001.jpeg
# copying image 15
# IM-0524-0001.jpeg
# copying image 16
# NORMAL2-IM-0852-0001.jpeg
# copying image 17
# IM-0384-0001.jpeg
# copying image 18
# IM-0395-0001.jpeg
# copying image 19
# NORMAL2-IM-1173-0001.jpeg
# copying image 20
# NORMAL2-IM-0662-0001.jpeg
# copying image 21
# IM-0717-0001.jpeg
# copying image 22
# NORMAL2-IM-0976-0001.jpeg
# copying image 23
# ...

# %% [markdown]
# ## Covid Train and Test Data

# %%
#COVID
image_names= os.listdir("Dataset/Covid")
image_names

#Test-covid
for i in range(66):
    image_name= image_names[i]
    image_path= os.path.join("Dataset/Covid", image_name)
    
    target_path= os.path.join("Dataset/Test/Covid", image_name)
    
    shutil.copy2(image_path, target_path)
    delete = f"Dataset/Covid/{image_name}"
    os.remove(delete)

# %%
#Train-covid
image_names= os.listdir("Dataset/Covid")
image_names

for i in range(130):
    image_name= image_names[i]
    image_path= os.path.join("Dataset/Covid", image_name)
    
    target_path= os.path.join("Dataset/Train/Covid", image_name)
    
    shutil.copy2(image_path, target_path)
    delete = f"Dataset/Covid/{image_name}"
    os.remove(delete)

# %% [markdown]
# ## Normal test and train data

# %%
#Normal
image_names= os.listdir("Dataset/Normal")
image_names

#Test-Normal
for i in range(66):
    image_name= image_names[i]
    image_path= os.path.join("Dataset/Normal", image_name)
    
    target_path= os.path.join("Dataset/Test/Normal/", image_name)
    
    shutil.copy2(image_path, target_path)
    delete = f"Dataset/Normal/{image_name}"
    os.remove(delete)

# %%
#Train-Normal
image_names= os.listdir("Dataset/Normal")
image_names

for i in range(196-66):
    image_name= image_names[i]
    image_path= os.path.join("Dataset/Normal", image_name)
    print(image_name)
    target_path= os.path.join("Dataset/Train/Normal", image_name)
    
    shutil.copy2(image_path, target_path)
    delete = f"Dataset/Normal/{image_name}"
    os.remove(delete)
# Out:
# IM-0599-0001.jpeg
# IM-0608-0001-0002.jpeg
# IM-0612-0001-0002.jpeg
# IM-0629-0001-0001.jpeg
# IM-0629-0001-0003.jpeg
# IM-0636-0001.jpeg
# IM-0650-0001.jpeg
# IM-0659-0001.jpeg
# IM-0660-0001-0001.jpeg
# IM-0663-0001.jpeg
# IM-0666-0001-0001.jpeg
# IM-0667-0001.jpeg
# IM-0675-0001.jpeg
# IM-0676-0001.jpeg
# IM-0688-0001.jpeg
# IM-0698-0001.jpeg
# IM-0702-0001.jpeg
# IM-0704-0001.jpeg
# IM-0709-0001.jpeg
# IM-0712-0001.jpeg
# IM-0713-0001.jpeg
# IM-0717-0001.jpeg
# IM-0733-0001.jpeg
# IM-0739-0001.jpeg
# IM-0752-0001.jpeg
# IM-0753-0001.jpeg
# IM-0764-0001.jpeg
# NORMAL2-IM-0390-0001.jpeg
# NORMAL2-IM-0393-0001.jpeg
# NORMAL2-IM-0394-0001.jpeg
# NORMAL2-IM-0414-0001.jpeg
# NORMAL2-IM-0416-0001-0002.jpeg
# NORMAL2-IM-0416-0001.jpeg
# NORMAL2-IM-0419-0001.jpeg
# NORMAL2-IM-0427-0001.jpeg
# NORMAL2-IM-0428-0001.jpeg
# NORMAL2-IM-0443-0001.jpeg
# NORMAL2-IM-0485-0001.jpeg
# NORMAL2-IM-0486-0001.jpeg
# NORMAL2-IM-0493-0001.jpeg
# NORMAL2-IM-0529-0001.jpeg
# NORMAL2-IM-0552-0001.jpeg
# ...
